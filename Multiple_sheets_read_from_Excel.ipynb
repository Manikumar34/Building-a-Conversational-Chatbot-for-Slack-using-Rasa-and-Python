# %% [markdown]
# <a href="https://colab.research.google.com/github/Manikumar34/Building-a-Conversational-Chatbot-for-Slack-using-Rasa-and-Python/blob/master/Multiple_sheets_read_from_Excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

workbook_url = '/content/drive/My Drive/Colab Notebooks/CCTrendChart.xlsx'
single_df = pd.read_excel(workbook_url,header=[1,2,3] ,sheet_name=None)
single_df.keys()
single_df['Santoor'].tail(50)
single_df
df = pd.concat(single_df, ignore_index=True)
df
df.to_excel("output.xlsx")
# Out:
# {'ALL-Santoor':      Unnamed: 0_level_0     PC 4  ...    LastYear            Goly
#              ALL Santoor      WK1  ...   1920-QTR2               %
#     Chandigar + Himachal   5.0103  ...   26.664628 16.215639685654
#  0             Deharadun   0.9135  ...   69.386004       11.695229
#  1             Ghaziabad   4.2336  ...  137.172060        3.784532
#  2                Ambala   0.6489  ...    9.563100       72.384436
#  3                 Delhi   0.4743  ...   15.254178       22.720398
#  4               UP East   4.1724  ...   61.275363       51.868202
#  ..                  ...      ...  ...         ...             ...
#  75                Total  568.864  ...         NaN             NaN
#  76                  NaN      NaN  ...         NaN             NaN
#  77          MatSubGroup      WK1  ...         NaN             NaN
#  78          ALL Santoor    415.2  ...         NaN             NaN
#  79                Total    415.2  ...         NaN             NaN
#
# ...
